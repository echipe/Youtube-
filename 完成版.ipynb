# %%
import numpy as np
import numpy.random as random
import scipy as sp
import pandas as pd
from pandas import Series, DataFrame
import statistics
#可視化ライブラリ
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
sns.set()

#機械学習ライブラリ
import sklearn

#小数点第3位まで表示
# %precision 3

#グラフで日本語を使えるようにする
# !pip install japanize_matplotlib
import japanize_matplotlib

import requests
import time
import re
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timezone
import numpy as np

API_KEY = "AIzaSyBbGxXKUGr00jzd_BhCxVMOz3chXlIDt90"
CHANNEL_ID = ""
ch_id={"UCli_j3KPGhsF1Mv1AK17UPA","UCUCeZaZeJbEYAAzvMgrKOPQ","UCQVhrypJhw1HxuRV4gX6hoQ","UCNMn4Nhl-E3iaSMab0Y_b4A","UCCdibO9eRKJIre22DKDNqug","UChVflUz2J_jaaqYjXqvpmQA","UCVvaL0oaZbvWNTa-xPeTxNw","UCzycs8MqvIY4nXWwS-v4J9g","UCpFgmZm65yOU5X-hmWkWjuw","UC5jLCyltbnart3k4iLFQvZg","UCP7Gw_YZAuh4Yg2fcdcuumQ"}
corrs_d=[]
corrs_l=[]
# ---------------------------
# duration → 秒
# ---------------------------
def parse_duration(duration):
    pattern = r'PT((\d+)H)?((\d+)M)?((\d+)S)?'
    match = re.match(pattern, duration)

    # The previous fix addressed `match` being None. Adding this check for safety.
    if match is None:
        return 0  # Return 0 or handle error as appropriate for invalid duration

    hours = int(match.group(2)) if match.group(2) else 0
    minutes = int(match.group(4)) if match.group(4) else 0
    seconds = int(match.group(6)) if match.group(6) else 0

    return hours * 3600 + minutes * 60 + seconds


# ---------------------------
# 音楽動画フィルタ
# ---------------------------
def is_music_video(title, duration):
    t = title.lower()

    if duration <= 60:
        return False

    if duration > 600:
        return False

    exclude = ["interview", "対談", "making", "behind", "teaser", "trailer","コラボレーション","ライブ",Live]
    if any(word in t for word in exclude):
        return False

    include = ["mv", "music video", "official"]
    if any(word in t for word in include):
        return True

    if 120 <= duration <= 480:
        return True

    return False


# ---------------------------
# API
# ---------------------------
def get_uploads_playlist_id(channel_id):
    url = "https://www.googleapis.com/youtube/v3/channels"
    return requests.get(url, params={
        "part": "contentDetails",
        "id": channel_id,
        "key": API_KEY
    }).json()["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"]


def get_all_videos(playlist_id):
    videos = []
    token = None

    while True:
        res = requests.get(
            "https://www.googleapis.com/youtube/v3/playlistItems",
            params={
                "part": "snippet,contentDetails",
                "playlistId": playlist_id,
                "maxResults": 50,
                "pageToken": token,
                "key": API_KEY
            }
        ).json()

        for item in res["items"]:
            videos.append({
                "videoId": item["contentDetails"]["videoId"],
                "title": item["snippet"]["title"],
                "publishedAt": item["contentDetails"]["videoPublishedAt"]
            })

        token = res.get("nextPageToken")
        if not token:
            break

        time.sleep(0.1)

    return videos


def get_video_details(ids):
    return requests.get(
        "https://www.googleapis.com/youtube/v3/videos",
        params={
            "part": "contentDetails,statistics",
            "id": ",".join(ids),
            "key": API_KEY
        }
    ).json()


# ---------------------------
# データ収集
# ---------------------------
def collect_data():
    playlist_id = get_uploads_playlist_id(CHANNEL_ID)
    videos = get_all_videos(playlist_id)

    rows = []

    for i in range(0, len(videos), 50):
        batch = videos[i:i+50]
        ids = [v["videoId"] for v in batch]

        details = get_video_details(ids)

        for item in details["items"]:
            vid = item["id"]
            # Add a check for 'duration' key
            if "duration" not in item["contentDetails"]:
                continue # Skip if duration is not available

            duration = parse_duration(item["contentDetails"]["duration"])
            meta = next(v for v in batch if v["videoId"] == vid)

            if not is_music_video(meta["title"], duration):
                continue

            stats = item.get("statistics", {})
            views = int(stats.get("viewCount", 0))
            likes = int(stats.get("likeCount", 0))

            rows.append({
                "title": meta["title"],
                "duration_sec": duration,
                "views": views,
                "likes": likes,
                "publishedAt": meta["publishedAt"]
            })

        time.sleep(0.1)

    df = pd.DataFrame(rows)

    # ---------------------------
    # 補正（重要）
    # ---------------------------
    df["publishedAt"] = pd.to_datetime(df["publishedAt"], utc=True)
    now = datetime.now(timezone.utc)

    df["days"] = (now - df["publishedAt"]).dt.days + 1
    df["views_per_day"] = df["views"] / df["days"]

    return df


# ---------------------------
# 可視化
# ---------------------------
def visualize(df):
    # Set Japanese font
    plt.rcParams['font.family'] = 'IPAexGothic' # Ensure Japanese font is used

    # jitter（重なり対策）
    x = df["likes"] + np.random.normal(0, df["likes"].std()*0.01, len(df))
    y = df["views_per_day"]

    # ---------------------------
    # 散布図
    # ---------------------------
    plt.figure()

    plt.scatter(
        x,
        y,
        alpha=0.5,
        s=8,
        color="blue"
    )

    plt.xscale("log")
    plt.yscale("log")

    plt.xlabel("高評価数（log）")
    plt.ylabel("1日あたり再生回数（log）")
    plt.title("高評価数と再生回数")
    plt.tight_layout() # Adjust layout to prevent labels from being cut off
    plt.show()


# ---------------------------
# 分析
# ---------------------------
def analyze(df):
    print("\n==== 相関係数 ====")
    print(df[["duration_sec", "likes", "views_per_day"]].corr())
    corrs_l.append(float(df["likes"].corr(df["views_per_day"])))
    print("\n==== 1日当たりの再生回数ランキング ====")
    print(
        df.sort_values("views_per_day", ascending=False)[
            ["title", "views_per_day", "views"]
        ].head(10)
    )

# ---------------------------
# 動画時間と再生回数
# ---------------------------
def analyze_duration(df):
    # Set Japanese font
    plt.rcParams['font.family'] = 'IPAexGothic' # Ensure Japanese font is used

    print("\n==== 動画時間と再生回数 相関 ====")

    # 相関係数
    corr = df["duration_sec"].corr(df["views_per_day"])
    print("相関係数:", corr)
    corrs_d.append(float(corr))

    # ---------------------------
    # 散布図
    # ---------------------------
    plt.figure()

    plt.scatter(
        df["duration_sec"],
        df["views_per_day"],
        alpha=0.5,
        s=8,
        color="blue"
    )

    plt.yscale("log")

    plt.xlabel("動画時間（秒）")
    plt.ylabel("1日あたり再生回数（log）")
    plt.title("動画時間と再生回数")
    plt.tight_layout() # Adjust layout to prevent labels from being cut off
    plt.show()
# ---------------------------
# 実行
# ---------------------------
def do(q):
 if __name__ == "__main__":
    global CHANNEL_ID
    CHANNEL_ID=q
    df = collect_data()

    print("\nデータサンプル:")
    print(df.head())

    analyze(df)
    visualize(df)
    analyze_duration(df)
    plt.rcParams['font.family'] = 'IPAexGothic' # Ensure Japanese font is used

    # 動画の長さをカテゴリ分け（例: 0-120秒, 120-240秒, etc.）
    bins = list(range(0, 481, 30)) + [np.inf] # 30秒刻みで480秒まで、それ以降をまとめる
    labels = [f'{i}-{i+30}s' for i in range(0, 480, 30)] + ['480s+'] # ラベルも30秒刻みに変更
    df['duration_bin'] = pd.cut(df['duration_sec'], bins=bins, labels=labels, right=False)



    # 各時間帯の1日あたり平均再生回数を計算
    duration_views = df.groupby('duration_bin', observed=False)['views_per_day'].mean().reset_index()

    plt.figure(figsize=(12, 6))
    sns.barplot(x='duration_bin', y='views_per_day', data=duration_views, palette='magma', hue='duration_bin', legend=False)
    plt.xlabel("動画の長さ (秒)")
    plt.ylabel("1日あたり平均再生回数")
    plt.title("動画時間帯別 1日あたり平均再生回数")
    plt.xticks(rotation=45) # ラベルが重なる場合のために回転
    plt.tight_layout()
    plt.show()
for ch in ch_id:
 do(ch)
print(f"相関係数(高評価数)：{corrs_l}")
print(f"相関係数(動画時間)：{corrs_d}")
print(f"相関係数の平均(高評価数)：{statistics.mean(corrs_l)}")
print(f"相関係数の平均(動画時間)：{statistics.mean(corrs_d)}")
# Out:
# Requirement already satisfied: japanize_matplotlib in /usr/local/lib/python3.12/dist-packages (1.1.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from japanize_matplotlib) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->japanize_matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->japanize_matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->japanize_matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->japanize_matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib->japanize_matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->japanize_matplotlib) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->japanize_matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->japanize_matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->japanize_matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->japanize_matplotlib) (1.17.0)
#
# データサンプル:
#                                                title  duration_sec    views  \
# 0  サカナクション / enough from「SAKANAQUARIUM 2025 "怪獣”」...           419   317944
# 1           【レコード会社スタッフが見つめ続けた「怪獣」の裏側】-Digest Movie-           155    61514
# 2                       サカナクション / いらない　-Music Video-           267  6864627
# 3                       サカナクション / いらない（instrumental）           227   108294
# 4               サカナクション / 新宝島　-Music Video 振付サンプル映像-           476  1211372
#
#     likes               publishedAt  days  views_per_day
# 0   14234 2026-03-18 09:00:42+00:00   114    2788.982456
# 1    7643 2026-03-16 09:01:22+00:00   116     530.293103
# 2  120463 2026-03-05 15:00:07+00:00   126   54481.166667
# 3    7753 2026-02-11 09:00:36+00:00   149     726.805369
# 4   37296 2025-10-10 09:00:04+00:00   273    4437.260073
#
# ==== 相関係数 ====
#                duration_sec     likes  views_per_day
# duration_sec       1.000000 -0.067465      -0.056093
# likes             -0.067465  1.000000       0.732463
# views_per_day     -0.056093  0.732463       1.000000
#
# ==== 1日当たりの再生回数ランキング ====
#                                                 title  views_per_day  \
# 7                          サカナクション / 怪獣　-Music Video-  171579.679834
# 46                        サカナクション / 新宝島　-Music Video-   68768.942893
# 2                        サカナクション / いらない　-Music Video-   54481.166667
# 26                    サカナクション / 忘れられないの　-Music Video-   20646.378882
# 6   サカナクション / ミュージック from LIVE Blu-ray/DVD「SAKANAQ...   15167.154989
# 45                      サカナクション / 夜の踊り子　-Music Video-   13241.372589
# 35                     サカナクション / 多分、風。  -Music Video-   11282.191982
# 25                         サカナクション / モス　-Music Video-    7676.844288
# 13                 サカナクション / ショック！　-Music Live Video-    5123.863469
# 33    ARASHI - ワイルド アット ハート [Official Music Video]   20202.729642  12404476
# ==== 動画時間と再生回数 相関 ====
# 相関係数: 0.05909691091925472
# データサンプル:
#                                                title  duration_sec    views  \
# 0  ONE OK ROCK - C.U.R.I.O.S.I.T.Y. [DETOX JAPAN ...           234   491631
# 1  ONE OK ROCK - Tiny Pieces [Official Clip from ...            66   153328
# 2  ONE OK ROCK - Renegades [Official Clip from "D...            66   195415
# 3  ONE OK ROCK - Party's Over [DETOX JAPAN TOUR 2...           240  1435995
# 4  ONE OK ROCK - This Can’t Be Us [Official Lyric...           265  2385794
#
#    likes               publishedAt  days  views_per_day
# 0  25668 2026-07-03 03:04:48+00:00     7   70233.000000
# 1   9262 2026-06-30 04:39:52+00:00    10   15332.800000
# 2   7725 2026-06-17 10:34:23+00:00    23    8496.304348
# 3  28368 2026-04-30 04:00:17+00:00    71   20225.281690
# 4  66643 2025-10-03 05:17:42+00:00   280    8520.692857
#
# ==== 相関係数 ====
#                duration_sec     likes  views_per_day
# duration_sec       1.000000  0.087805      -0.042559
# likes              0.087805  1.000000       0.670433
# views_per_day     -0.042559  0.670433       1.000000
#
# ==== 1日当たりの再生回数ランキング ====
#                                                  title  views_per_day  \
# 0    ONE OK ROCK - C.U.R.I.O.S.I.T.Y. [DETOX JAPAN ...   70233.000000
# 116  ONE OK ROCK - The Beginning [Official Music Vi...   47193.300177
# 114  ONE OK ROCK - Clock Strikes [Official Music Vi...   29270.364940
# 22   ONE OK ROCK - Delusion:All [OFFICIAL MUSIC VIDEO]   25953.590659
# 79      ONE OK ROCK: Stand Out Fit In [OFFICIAL VIDEO]   24859.063532
# 77         ONE OK ROCK: Wasted Nights [OFFICIAL VIDEO]   23174.691090
# 74   ONE OK ROCK - We are [Official Video from AMBI...   22315.844304
# 68   ONE OK ROCK - Renegades Japanese Version [OFFI...   21992.694924
# 34   ONE OK ROCK × Monster Hunter Now - "Make It Ou...   20692.545889
# 72   ONE OK ROCK - Wasted Nights [Official Video fr...   20281.214525
#
#          views
# 0       491631
# 116  239600385
# 114  142927192
# 22    18894214
# 79    69257351
# 77    62942461
# 74    56615297
# 68    42028040
# 34    21644403
# 72    42448582
# ==== 動画時間と再生回数 相関 ====
# 相関係数: -0.042559031617362915
# データサンプル:
#                                                title  duration_sec     views  \
# 0                   米津玄師 - 烏　Kenshi Yonezu -  Karasu           258   9293495
# 1  米津玄師「ピースサイン」RIAAゴールド認定 "Peace Sign" has offici...            97    223860
# 2  『チェンソーマン レゼ篇』スペシャル花火 ― IRIS OUT / JANE DOE ― ／...           471   1187466
# 3  米津玄師 – IRIS OUT「第76回NHK紅白歌合戦」　Kenshi Yonezu – ...           259  32133419
# 4  米津玄師 - さよーならまたいつか！「第75回NHK紅白歌合戦」 Kenshi Yonezu...           285   9362174
#
#     likes               publishedAt  days  views_per_day
# 0  176797 2026-06-18 11:00:07+00:00    22  422431.590909
# 1   18807 2026-05-13 10:00:52+00:00    58    3859.655172
# 2   45675 2026-01-09 07:00:40+00:00   182    6524.538462
# 3  427460 2026-01-09 07:00:26+00:00   182  176557.247253
# 4  172477 2026-01-09 07:00:13+00:00   182   51440.516484
#
# ==== 相関係数 ====
#                duration_sec     likes  views_per_day
# duration_sec       1.000000 -0.061906      -0.167637
# likes             -0.061906  1.000000       0.618208
# views_per_day     -0.167637  0.618208       1.000000
#
# ==== 1日当たりの再生回数ランキング ====
#                                                 title  views_per_day  \
# 10                     米津玄師  Kenshi Yonezu - IRIS OUT  708894.147651
# 0                    米津玄師 - 烏　Kenshi Yonezu -  Karasu  422431.590909
# 50                       米津玄師  Kenshi Yonezu  - Lemon  321388.432406
# 8   米津玄師, 宇多田ヒカル Kenshi Yonezu, Hikaru Utada -  JA...  305653.748276
# 7   劇場版『チェンソーマン レゼ篇』オープニングムービー 　主題歌：米津玄師「IRIS OUT」...  179687.471014
# 3   米津玄師 – IRIS OUT「第76回NHK紅白歌合戦」　Kenshi Yonezu – ...  176557.247253
# 36                      米津玄師 Kenshi Yonezu - KICKBACK  174538.011078
# 27  米津玄師 - さよーならまたいつか！ Kenshi Yonezu - Sayonara, M...  157611.926740
# 43                 米津玄師 - 感電   Kenshi Yonezu - KANDEN  120990.576449
# 55         米津玄師 - ピースサイン , Kenshi Yonezu - Peace Sign  102083.199458
#
#         views
# 10  211250456
# 0     9293495
# 50  981841661
# 8    88639587
# 7    49593742
# 3    32133419
# 36  236324467
# 27  129084168
# 43  265090353
# 55  338814139
# ==== 動画時間と再生回数 相関 ====
# 相関係数: -0.16763721190552044
# データサンプル:
#                                                title  duration_sec    views  \
# 0            sumika / Blue [テレビ東京「超⚡️超音波」SONIC LIVE]           298   123834
# 1           sumika / Honto [テレビ東京「超⚡️超音波」SONIC LIVE]           228   121494
# 2    sumika / Honto【『映画ドラえもん 新・のび太の海底鬼岩城』公開直前 特別試写会】           244  1708146
# 3                        sumika / Honto【Music Video】           239  4791128
# 4  sumika / 春夏秋冬【sumika Film #17 sumika FANCLUB L...           285   175292
#
#    likes               publishedAt  days  views_per_day
# 0   2530 2026-03-22 11:00:32+00:00   110    1125.763636
# 1   2407 2026-03-21 12:00:49+00:00   111    1094.540541
# 2  14813 2026-02-27 13:00:21+00:00   133   12843.203008
# 3  38473 2026-02-25 11:00:08+00:00   135   35489.837037
# 4   3937 2026-02-06 11:00:27+00:00   154    1138.259740
#
# ==== 相関係数 ====
#                duration_sec     likes  views_per_day
# duration_sec       1.000000  0.046611       0.045728
# likes              0.046611  1.000000       0.671307
# views_per_day      0.045728  0.671307       1.000000
#
# ==== 1日当たりの再生回数ランキング ====
#                                                 title  views_per_day     views
# 3                         sumika / Honto【Music Video】   35489.837037   4791128
# 84                       sumika / Lovers【Music Video】   24572.698073  93105953
# 74                       sumika / フィクション【Music Video】   19789.428952  59467234
# 18                           sumika / 運命【Music Video】   13266.439467  10958079
# 2     sumika / Honto【『映画ドラえもん 新・のび太の海底鬼岩城』公開直前 特別試写会】   12843.203008   1708146
# 64                           sumika / 願い【Music Video】   11148.923680  27024991
